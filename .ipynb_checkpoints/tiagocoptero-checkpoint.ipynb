# %% [markdown]
# 1. follow @tgiorgetti on twitter and steal/download his videos

# %% [markdown]
# 2. ffmpeg -ss 00:00 -i stolen_video.mp4 -t 00:04 images_%03d.tiff

# %%
# %matplotlib inline
from os import listdir
from os.path import isfile, join
import os, glob
import matplotlib.image as img
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
mypath='~/little_project/'
lista = []
for infile in sorted(glob.glob( os.path.join(mypath, '*.tiff')) ):
    lista.append(infile)

# %%
cubo0,cubo1,cubo2 = [],[],[]
for i in range(len(lista)):
    #print(lista[i])
    im = img.imread(lista[i])
    im0 = im[70:300,40:270,0]
    im1 = im[70:300,40:270,1]
    im2 = im[70:300,40:270,2]
    val0 = np.sum(im0)
    val1 = np.sum(im1)
    val2 = np.sum(im2)
    cubo0.append(val0)
    cubo1.append(val1)
    cubo2.append(val2)

# %%
plt.imshow(im0)

# %%
curva0 = signal.detrend(cubo0)
curva1 = signal.detrend(cubo1)
curva2 = signal.detrend(cubo2)

# %%
c0 = (curva0-np.min(curva0))/np.max(curva0)
c1 = (curva0-np.min(curva1))/np.max(curva1)
c2 = (curva0-np.min(curva2))/np.max(curva2)

# %%
transit = c0+c1+c2
transit = (transit -np.min(transit))/np.max(transit)-1.0

# %%
plt.plot(transit,'ro')
plt.plot(transit,'k--')
plt.xlabel('time')
plt.ylabel('brightness')
plt.savefig('tiagocoptero.png')
